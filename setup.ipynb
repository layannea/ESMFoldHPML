# %%
import os, time
import sys

#model_name = "esmfold_v0.model" 
model_name = "esmfold.model"

if not os.path.isfile(model_name):
    
  # download esmfold params
  os.system("apt-get install aria2 -qq")
  os.system(f"aria2c -q -x 16 https://colabfold.steineggerlab.workers.dev/esm/{model_name} &")

  if not os.path.isfile("finished_install"):
    # install libs
    print("installing libs...")
    os.system(f"{sys.executable} -m pip install -q matplotlib omegaconf pytorch_lightning biopython ml_collections einops py3Dmol modelcif scipy jax dm-tree wandb nbformat")
    os.system(f"{sys.executable} -m pip install -q git+https://github.com/NVIDIA/dllogger.git")

    print("installing openfold...")
    # install openfold
    os.system(f"{sys.executable} -m pip install -q git+https://github.com/sokrypton/openfold.git --no-build-isolation")

    print("installing esmfold...")
    # install esmfold
    os.system(f"{sys.executable} -m pip install -q git+https://github.com/sokrypton/esm.git")
    os.system("touch finished_install")

    # install TMalign
    os.system("wget https://zhanggroup.org/TM-align/TMalign")
    os.system("chmod +x TMalign")
      
  # wait for Params to finish downloading...
  while not os.path.isfile(model_name):
    time.sleep(5)
  if os.path.isfile(f"{model_name}.aria2"):
    print("downloading params...")
  while os.path.isfile(f"{model_name}.aria2"):
    time.sleep(5)
# Out:
# installing libs...
# sh: apt-get: command not found
# sh: aria2c: command not found
#   DEPRECATION: Building 'antlr4-python3-runtime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'antlr4-python3-runtime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.16.3 which is incompatible.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ...
